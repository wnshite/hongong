# %%
import pandas as pd

df = pd.read_csv('data/Fish.csv')

# %%
cond = df['Species'].isin(['Bream', 'Smelt'])
fish_data = df.loc[cond, ['Length2', 'Weight']]
fish_data.head()
# Out:
#    Length2  Weight
# 0     25.4   242.0
# 1     26.3   290.0
# 2     26.5   340.0
# 3     29.0   363.0
# 4     29.0   430.0

# %%
fish_target = df.loc[cond, ['Species']]
#fish_target   ## 이름 자체를 활용

# %%
from sklearn.model_selection import train_test_split

# %%
len(train_target)
# Out:
# 36

# %%
test_target
# Out:
#     Species
# 154   Smelt
# 14    Bream
# 152   Smelt
# 34    Bream
# 7     Bream
# 4     Bream
# 20    Bream
# 6     Bream
# 8     Bream
# 30    Bream
# 18    Bream
# 26    Bream
# 9     Bream

# %%
# 사이킷런으로 훈련세트와 테스트 세트 나누기...
from sklearn.neighbors import KNeighborsClassifier
kn = KNeighborsClassifier()

# %%
kn.fit(train_input, train_target['Species'])
# Out:
# KNeighborsClassifier()

# %%
kn.score(test_input, test_target['Species'])
# Out:
# 1.0

# %%
kn.predict([[25, 150]])
# Out:
# C:\Users\1-01\Desktop\DAMF2\ml\venv\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# array(['Smelt'], dtype=object)

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(train_input['Length2'], train_input['Weight'])
plt.scatter(25, 150, marker='^')

# %%
kn.kneighbors([[25, 150]])
# Out:
# C:\Users\1-01\Desktop\DAMF2\ml\venv\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# (array([[ 92.00086956, 130.48375378, 130.73859415, 137.17988191,
#          138.32150953]]),
#  array([[ 9, 22, 34,  6, 17]]))

# %%
mean = train_input.mean()
std = train_input.std()
print(mean)
print(std)
# Out:
# Length2     27.605556
# Weight     459.383333
# dtype: float64
# Length2      9.745503
# Weight     319.291702
# dtype: float64

# %%
train_scaled = (train_input - mean) /std

# %%
plt.scatter(train_scaled['Length2'], train_scaled['Weight'])  ## 각각의 비율이 동일해짐.

# %%
kn.fit(train_scaled, train_target['Species'])
# Out:
# KNeighborsClassifier()

# %%
test_scaled = (test_input - mean) /std

# %%
kn.score(test_scaled, test_target)
# Out:
# 1.0

# %%
new = ()
